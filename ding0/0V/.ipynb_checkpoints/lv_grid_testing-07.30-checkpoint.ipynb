# %% [markdown]
# <img src="https://gist.githubusercontent.com/nesnoj/6ee605cd3494fa6e3e848385c4afbe19/raw/a883b1bdc69c0c5bbb0b00ba92f43033aa86ec64/dingo_model.png" alt="DINGO Model" width="800"  align="center">

# %%
# %%capture

from ding0.core import NetworkDing0
from ding0.tools.logger import setup_logger
from ding0.tools.results import save_nd_to_pickle
from ding0.tools.plots import plot_mv_topology
from egoio.tools import db
from sqlalchemy.orm import sessionmaker
import oedialect

from ding0.tools import results


# create new network
nd = NetworkDing0(name='network')



# set ID of MV grid district
mv_grid_districts = [40] # fn

# %%
import networkx as nx # nx.draw()

# %%
engine = db.connection(section='oedb_dialect', readonly=True)
session = sessionmaker(bind=engine)()

# %%
ding0_default=False

# %%
graph, node_coords_dict, row_geo_area = nd.import_mv_grid_districts(session, ding0_default, mv_grid_districts_no=mv_grid_districts)

# %%
#graph.__dict__

# %%
#graph_ox.__dict__

# %%
nx.draw(graph, node_coords_dict, node_size=10)

# %%
ox.plot_graph(graph_ox)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.plot_graph(graph)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
import osmnx as ox

# %%
graph_ox = ox.graph_from_polygon(wkt.loads(row_geo_area), simplify=False, truncate_by_edge=True, retain_all=False, network_type='walk')

nodes_ox, edges_ox = ox.graph_to_gdfs(graph_ox)

# %%
nodes_ding0, edges_ding0 = ox.graph_to_gdfs(graph)

# %%
nodes_ox.head(1)
# Out:
#                   y          x  street_count highway  \
# osmid
# 27200071  52.555457  13.391461             4     NaN
#
#                            geometry
# osmid
# 27200071  POINT (13.39146 52.55546)

# %%
nodes_ding0.head(1)
# Out:
#                   x          y                  geometry
# osmid
# 329334526  9.486881  47.703176  POINT (9.48688 47.70318)

# %%
edges_ox.sort_index().head(4)
# Out:
#                               osmid     ref         name       highway  \
# u         v          key
# 59975167  329334540  0     39772847  L 328a  Hauptstraße     secondary
#           3071960768 0     39772847  L 328a  Hauptstraße     secondary
# 59975168  431242851  0     39772846  L 328a  Hauptstraße     secondary
# 260386717 3071952178 0    119067449     NaN     Einödweg  unclassified
#
#                          maxspeed  oneway   length access  \
# u         v          key
# 59975167  329334540  0         50   False   25.431    NaN
#           3071960768 0         50   False  131.210    NaN
# 59975168  431242851  0        100   False   85.495    NaN
# 260386717 3071952178 0        NaN   False   34.100    NaN
#
#                                                                  geometry
# u         v          key
# 59975167  329334540  0    LINESTRING (9.48809 47.70266, 9.48814 47.70289)
#           3071960768 0    LINESTRING (9.48809 47.70266, 9.48784 47.70149)
# 59975168  431242851  0    LINESTRING (9.48768 47.70066, 9.48783 47.70142)
# 260386717 3071952178 0    LINESTRING (9.47896 47.70423, 9.47941 47.70425)

# %%
# convert undirected graph to digraph
digraph = nx.MultiGraph(graph)
digraph = digraph.to_directed()
digraph.number_of_edges()
# Out:
# 270

# %%
graph.number_of_edges()
# Out:
# 135

# %%
graph_ox.number_of_edges()
# Out:
# 226

# %%
len(edges_ding0.loc[edges_ding0.osmid==39772847]), len(edges_ding0.loc[edges_ding0.osmid==39772847])
# Out:
# (6, 6)

# %%
edges_ding0.loc[edges_ding0.osmid==39772847]
# Out:
#                                length     osmid    highway  \
# u          v          key
# 331523269  3076312536 0    106.964646  39772847  secondary
#            476780224  0     52.039932  39772847  secondary
# 431242851  3071960768 0      7.585870  39772847  secondary
# 3071960768 59975167   0    131.205944  39772847  secondary
# 59975167   329334540  0     25.429728  39772847  secondary
# 329334540  3076312536 0     12.018157  39772847  secondary
#
#                                                                   geometry
# u          v          key
# 331523269  3076312536 0    LINESTRING (9.48843 47.70394, 9.48817 47.70299)
#            476780224  0    LINESTRING (9.48843 47.70394, 9.48858 47.70439)
# 431242851  3071960768 0    LINESTRING (9.48783 47.70142, 9.48784 47.70149)
# 3071960768 59975167   0    LINESTRING (9.48784 47.70149, 9.48809 47.70266)
# 59975167   329334540  0    LINESTRING (9.48809 47.70266, 9.48814 47.70289)
# 329334540  3076312536 0    LINESTRING (9.48814 47.70289, 9.48817 47.70299)

# %%
edges_ox.loc[edges_ox.osmid==39772847]
# Out:
#                               osmid     ref         name    highway maxspeed  \
# u          v          key
# 59975167   329334540  0    39772847  L 328a  Hauptstraße  secondary       50
#            3071960768 0    39772847  L 328a  Hauptstraße  secondary       50
# 329334540  3076312536 0    39772847  L 328a  Hauptstraße  secondary       50
#            59975167   0    39772847  L 328a  Hauptstraße  secondary       50
# 331523269  3076312536 0    39772847  L 328a  Hauptstraße  secondary       50
# 431242851  3071960768 0    39772847  L 328a  Hauptstraße  secondary       50
# 3071960768 59975167   0    39772847  L 328a  Hauptstraße  secondary       50
#            431242851  0    39772847  L 328a  Hauptstraße  secondary       50
# 3076312536 331523269  0    39772847  L 328a  Hauptstraße  secondary       50
#            329334540  0    39772847  L 328a  Hauptstraße  secondary       50
#
#                            oneway   length access  \
# u          v          key
# 59975167   329334540  0     False   25.431    NaN
#            3071960768 0     False  131.210    NaN
# 329334540  3076312536 0     False   12.018    NaN
#            59975167   0     False   25.431    NaN
# 331523269  3076312536 0     False  106.964    NaN
# 431242851  3071960768 0     False    7.586    NaN
# 3071960768 59975167   0     False  131.210    NaN
#            431242851  0     False    7.586    NaN
# 3076312536 331523269  0     False  106.964    NaN
#            329334540  0     False   12.018    NaN
#
#                                                                   geometry
# u          v          key
# 59975167   329334540  0    LINESTRING (9.48809 47.70266, 9.48814 47.70289)
#            3071960768 0    LINESTRING (9.48809 47.70266, 9.48784 47.70149)
# 329334540  3076312536 0    LINESTRING (9.48814 47.70289, 9.48817 47.70299)
#            59975167   0    LINESTRING (9.48814 47.70289, 9.48809 47.70266)
# 331523269  3076312536 0    LINESTRING (9.48843 47.70394, 9.48817 47.70299)
# 431242851  3071960768 0    LINESTRING (9.48783 47.70142, 9.48784 47.70149)
# 3071960768 59975167   0    LINESTRING (9.48784 47.70149, 9.48809 47.70266)
#            431242851  0    LINESTRING (9.48784 47.70149, 9.48783 47.70142)
# 3076312536 331523269  0    LINESTRING (9.48817 47.70299, 9.48843 47.70394)
#            329334540  0    LINESTRING (9.48817 47.70299, 9.48814 47.70289)

# %%
edges_ding0.sort_index().head(4)
# Out:
#                             length     osmid    highway  \
# u        v          key
# 59975167 329334540  0    25.429728  39772847  secondary
# 59975168 431242851  0    85.491170  39772846  secondary
# 59975169 3071960773 0    63.068225  39772846  secondary
# 59975170 260386738  0    46.922099  39772846  secondary
#
#                                                                 geometry
# u        v          key
# 59975167 329334540  0    LINESTRING (9.48809 47.70266, 9.48814 47.70289)
# 59975168 431242851  0    LINESTRING (9.48768 47.70066, 9.48783 47.70142)
# 59975169 3071960773 0    LINESTRING (9.48665 47.69795, 9.48685 47.69850)
# 59975170 260386738  0    LINESTRING (9.48643 47.69691, 9.48649 47.69733)

# %%
edges.head(1)
# Out:
#                            osmid     ref         name    highway maxspeed  \
# u        v         key
# 59975167 329334540 0    39772847  L 328a  Hauptstraße  secondary       50
#
#                         oneway  length access  \
# u        v         key
# 59975167 329334540 0     False  25.431    NaN
#
#                                                                geometry
# u        v         key
# 59975167 329334540 0    LINESTRING (9.48809 47.70266, 9.48814 47.70289)

# %%
#row_geo_area

# %%
from shapely import wkt

# %%
nx.draw(graph, node_coords_dict, node_size=10)

# %%
graph_ox.__dict__
# Out:
# {'edge_key_dict_factory': dict,
#  'graph_attr_dict_factory': dict,
#  'node_dict_factory': dict,
#  'node_attr_dict_factory': dict,
#  'adjlist_outer_dict_factory': dict,
#  'adjlist_inner_dict_factory': dict,
#  'edge_attr_dict_factory': dict,
#  'graph': {'created_date': '2021-07-30 10:28:34',
#   'created_with': 'OSMnx 1.1.1',
#   'crs': 'epsg:4326'},
#  '_node': {59975167: {'y': 47.7026593, 'x': 9.4880896, 'street_count': 2},
#   260386718: {'y': 47.7042024, 'x': 9.4801297, 'street_count': 2},
#   260386719: {'y': 47.7040554, 'x': 9.4809054, 'street_count': 3},
#   260386720: {'y': 47.7038677, 'x': 9.4808545, 'street_count': 2},
#   260386721: {'y': 47.7036168, 'x': 9.4814955, 'street_count': 3},
#   260386722: {'y': 47.7020756, 'x': 9.48151, 'street_count': 2},
#   329334521: {'y': 47.7026987, 'x': 9.4855897, 'street_count': 1},
#   329334526: {'y': 47.7031763, 'x': 9.4868813, 'street_count': 3},
#   329334529: {'y': 47.702901, 'x': 9.4879458, 'street_count': 2},
#   329334540: {'y': 47.7028857, 'x': 9.4881377, 'street_count': 3},
#   331517278: {'y': 47.703262, 'x': 9.486856, 'street_count': 2},
#   331517282: {'y': 47.7034047, 'x': 9.4868533, 'street_count': 2},
#   331517284: {'y': 47.7034893, 'x': 9.4869322, 'street_count': 2},
#   331517290: {'y': 47.7036968, 'x': 9.487096, 'street_count': 2},
#   331517294: {'y': 47.7039424, 'x': 9.4870964, 'street_count': 2},
#   331517296: {'y': 47.7039979, 'x': 9.4871167, 'street_count': 2},
#   331517300: {'y': 47.7040316, 'x': 9.4871513, 'street_count': 3},
#   331517308: {'y': 47.7042245, 'x': 9.483212, 'street_count': 2},
{0: {'osmid': 626721645,
#      'name': 'Ellenbergweg',
#      'highway': 'residential',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 12.359}},
#    329334529: {0: {'osmid': 626721645,
#      'name': 'Ellenbergweg',
#      'highway': 'residential',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 48.144}}},
#   3037986486: {443341571: {0: {'osmid': 37795705,
#      'name': 'Ellenbergweg',
#      'highway': 'residential',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 27.556}},
#    331519841: {0: {'osmid': 37795705,
#      'name': 'Ellenbergweg',
#      'highway': 'residential',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 14.113}}},
#   3037986492: {381941782: {0: {'osmid': 568517101,
#      'name': 'Lottenweilerweg',
#      'highway': 'track',
#      'access': 'forestry',
#      'oneway': False,
#      'length': 23.052}}},
#   3037986493: {3037986525: {0: {'osmid': 29882564,
#      'highway': 'track',
#      'oneway': False,
#      'length': 10.847}},
#    3037986501: {0: {'osmid': 29882564,
#      'highway': 'track',
#      'oneway': False,
#      'length': 48.052}}},
#   3037986501: {3037986493: {0: {'osmid': 29882564,
#      'highway': 'track',
#      'oneway': False,
#      'length': 48.052}}},
#   3037986518: {366519040: {0: {'osmid': 568517101,
#      'name': 'Lottenweilerweg',
#      'highway': 'track',
#      'access': 'forestry',
#      'oneway': False,
#      'length': 74.674}},
#    381941784: {0: {'osmid': 568517101,
#      'name': 'Lottenweilerweg',
#      'highway': 'track',
#      'access': 'forestry',
#      'oneway': False,
#      'length': 18.513}}},
#   3037986525: {329334521: {0: {'osmid': 29882564,
#      'highway': 'track',
#      'oneway': False,
#      'length': 22.147}},
#    3037986493: {0: {'osmid': 29882564,
#      'highway': 'track',
#      'oneway': False,
#      'length': 10.847}}},
#   3071952178: {443332268: {0: {'osmid': 119067449,
#      'name': 'Einödweg',
#      'highway': 'unclassified',
#      'oneway': False,
#      'length': 31.559}},
#    260386717: {0: {'osmid': 119067449,
#      'name': 'Einödweg',
#      'highway': 'unclassified',
#      'oneway': False,
#      'length': 34.1}}},
#   3071952179: {3071953087: {0: {'osmid': 37794950,
#      'name': 'Bäumlinger Weg',
#      'highway': 'unclassified',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 111.431}},
#    260386721: {0: {'osmid': 37794950,
#      'name': 'Bäumlinger Weg',
#      'highway': 'unclassified',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 53.456}}},
#   3071953083: {3071953090: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 21.426}},
#    3071953094: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 36.69}}},
#   3071953085: {3071953087: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 7.5}},
#    3071953092: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 3.341}}},
#   3071953086: {3071953092: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 3.422}},
#    3071953096: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 6.057}}},
#   3071953087: {260386722: {0: {'osmid': 37794950,
#      'name': 'Bäumlinger Weg',
#      'highway': 'unclassified',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 6.527}},
#    3071952179: {0: {'osmid': 37794950,
#      'name': 'Bäumlinger Weg',
#      'highway': 'unclassified',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 111.431}},
#    3071953085: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 7.5}}},
#   3071953088: {3071953095: {0: {'osmid': 37795133,
#      'name': 'Dorfweg',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 4.433}},
#    443337845: {0: {'osmid': 37795133,
#      'name': 'Dorfweg',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 6.326}}},
#   3071953089: {3071953094: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 4.836}}},
#   3071953090: {3071953096: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 48.558}},
#    3071953083: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 21.426}}},
#   3071953092: {3071953085: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 3.341}},
#    3071953086: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 3.422}}},
#   3071953094: {3071953083: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 36.69}},
#    3071953089: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 4.836}}},
#   3071953095: {443337114: {0: {'osmid': 37795133,
#      'name': 'Dorfweg',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 6.421}},
#    3071953088: {0: {'osmid': 37795133,
#      'name': 'Dorfweg',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 4.433}}},
#   3071953096: {3071953086: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 6.057}},
#    3071953090: {0: {'osmid': 302910640,
#      'name': 'Bäumlinger Weg',
#      'highway': 'residential',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 48.558}}},
#   3071960754: {3071960761: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 7.384}},
#    3071960771: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 3.971}}},
#   3071960758: {3071960763: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 4.527}},
#    3071960762: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 6.833}}},
#   3071960760: {3071960762: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 5.535}}},
#   3071960761: {3071960768: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 37.798}},
#    3071960754: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 7.384}}},
#   3071960762: {3071960758: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 6.833}},
#    3071960760: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 5.535}}},
#   3071960763: {3071960771: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 7.363}},
#    3071960758: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 4.527}}},
#   3071960768: {59975167: {0: {'osmid': 39772847,
#      'ref': 'L 328a',
#      'name': 'Hauptstraße',
#      'highway': 'secondary',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 131.21}},
#    431242851: {0: {'osmid': 39772847,
#      'ref': 'L 328a',
#      'name': 'Hauptstraße',
#      'highway': 'secondary',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 7.586}},
#    3071960761: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 37.798}}},
#   3071960771: {3071960754: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 3.971}},
#    3071960763: {0: {'osmid': 302910935,
#      'name': 'Hauptstraße',
#      'highway': 'residential',
#      'oneway': False,
#      'length': 7.363}}},
#   3076312536: {331523269: {0: {'osmid': 39772847,
#      'ref': 'L 328a',
#      'name': 'Hauptstraße',
#      'highway': 'secondary',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 106.964}},
#    329334540: {0: {'osmid': 39772847,
#      'ref': 'L 328a',
#      'name': 'Hauptstraße',
#      'highway': 'secondary',
#      'maxspeed': '50',
#      'oneway': False,
#      'length': 12.018}},
#    3076312548: {0: {'osmid': 303278577,
#      'highway': 'service',
#      'oneway': False,
#      'length': 52.439}}},
#   3076312548: {3076312536: {0: {'osmid': 303278577,
#      'highway': 'service',
#      'oneway': False,
#      'length': 52.439}}},
#   4452429946: {366519039: {0: {'osmid': 626712378,
#      'name': 'Lottenweilerweg',
#      'highway': 'unclassified',
#      'oneway': False,
#      'length': 28.21}}},
#   8095608341: {331517316: {0: {'osmid': 37795007,
#      'name': 'Lottenweilerweg',
#      'highway': 'residential',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 10.599}},
#    331517315: {0: {'osmid': 37795007,
#      'name': 'Lottenweilerweg',
#      'highway': 'residential',
#      'maxspeed': '30',
#      'oneway': False,
#      'length': 5.435}},
#    8095608342: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 12.187}}},
#   8095608342: {8095608343: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 10.949}},
#    8095608341: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 12.187}}},
#   8095608343: {8095608344: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 7.059}},
#    8095608342: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 10.949}}},
#   8095608344: {8095608349: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 5.445}},
#    8095608343: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 7.059}}},
#   8095608345: {8095608346: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 6.312}},
#    8095608349: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 5.287}}},
#   8095608346: {8095608348: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 3.176}},
#    8095608345: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 6.312}}},
#   8095608347: {8095608348: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 4.158}}},
#   8095608348: {8095608347: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 4.158}},
#    8095608346: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 3.176}}},
#   8095608349: {8095608345: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 5.287}},
#    8095608344: {0: {'osmid': 868521723,
#      'highway': 'service',
#      'oneway': False,
#      'length': 5.445}}},
#   8511000105: {443380156: {0: {'osmid': 916344671,
#      'highway': 'path',
#      'oneway': False,
#      'length': 15.637}}}},
#  'nodes': NodeView((59975167, 59975168, 260386717, 260386718, 260386719, 260386720, 260386721, 260386722, 329334500, 329334521, 329334526, 329334529, 329334540, 331517278, 331517282, 331517284, 331517290, 331517294, 331517296, 331517300, 331517302, 331517306, 331517308, 331517310, 331517312, 331517315, 331517316, 331517319, 331517321, 331517323, 331517325, 331519841, 331523269, 366519039, 366519040, 366519041, 381941782, 381941783, 381941784, 431242851, 443332268, 443335532, 443335533, 443336608, 443337114, 443337115, 443337117, 443337744, 443337745, 443337845, 443337846, 443338171, 443338172, 443338763, 443338764, 443338765, 443338766, 443339517, 443339518, 443341571, 443342795, 443380156, 1283292589, 1283292598, 2406271485, 2406271488, 2467314133, 3037961767, 3037961781, 3037961830, 3037986472, 3037986486, 3037986492, 3037986493, 3037986501, 3037986518, 3037986525, 3071952178, 3071952179, 3071953083, 3071953085, 3071953086, 3071953087, 3071953088, 3071953089, 3071953090, 3071953092, 3071953094, 3071953095, 3071953096, 3071960754, 3071960758, 3071960760, 3071960761, 3071960762, 3071960763, 3071960768, 3071960771, 3076312536, 3076312548, 4452429946, 8095608341, 8095608342, 8095608343, 8095608344, 8095608345, 8095608346, 8095608347, 8095608348, 8095608349, 8511000105))}

# %%
#graph, node_coords_dict = build_graph_from_ways(ways)
nx.draw(graph, node_coords_dict)

# %%
for way in ways:
    
    print(way)
    
    break

# %%
load_from_pkl=True

if load_from_pkl:
    
    print('LOAD DING0 GRID FROM PKL')

    grid_id=40
    nd = results.load_nd_from_pickle(filename='./config/tmp/ding0_grids__' + str(grid_id) + '.pkl')
    
    # should be closed before export
    nd.control_circuit_breakers(mode='open')


else:
    
    print('DING0.RUN()')
    
    nd.import_mv_grid_districts(session, ding0_default, mv_grid_districts, need_parameterization)
    nd.import_generators(session)

    nd.mv_parametrize_grid()
    nd.validate_grid_districts()
    
    build_lv_grid_default=True

    if build_lv_grid_default:

        nd.build_lv_grids()

    else:

        print('IMPLEMENT_MY_ROUTING')
        
        
    nd.mv_routing()
    
    nd.connect_generators()
    #nd.set_branch_ids()
    nd.set_circuit_breakers()
    
    
    nd.control_circuit_breakers(mode='open')
    nd.run_powerflow(session)
    
    nd.reinforce_grid()
    
    
    
    #nd.control_circuit_breakers(mode='close')
    #save_nd_to_pickle(nd, filename='ding0_grids__40.pkl')
# Out:
# LOAD DING0 GRID FROM PKL

# %%
import networkx as nx # to enable nx.draw()
import pandas as pd
from sqlalchemy import func              # check
from geoalchemy2.shape import to_shape 
from shapely.wkt import loads

# %%
from config.config_lv_grids_osm import get_config_osm     # check
from config.db_conn_local import create_session_osm       # check
from config.classes_db_conn.osm_load_classes import Buildings_with_Amenities, Building_wo_Amenity, Amenities_ni_Buildings, Way # check

# %%
from grid.lv_grid.routing import build_graph_from_ways, nearest_nodes, get_location_substation_at_pi
from grid.lv_grid.parameterization import parameterize_by_load_profiles
from grid.lv_grid.clustering import get_n_cluster, cluster_k_means

# %%
from grid.lv_grid.geo import get_Point_from_x_y, get_points_in_load_area, get_convex_hull_from_points

# %%
session_osm = create_session_osm() # check

# %%
# FOR TESTING REASONS SELECT ONE LOAD_AREA (Fallenbrunnen) BY ID
id_load_area_fallenbrunnen = '4544'

load_areas = []


for mv_grid_district in nd.mv_grid_districts():
    for load_area in mv_grid_district.lv_load_areas():
        
        
        if not load_area.is_aggregated:
                
            if id_load_area_fallenbrunnen in str(load_area):
                
                fn_fallenbrunnen_la  = load_area
                fn_fallenbrunnen_geo = fn_fallenbrunnen_la.geo_area
                
                #for lv_district in fn_fallenbrunnen_la._lv_grid_districts:
                # does not work due to one districtr has 1 lv station where trafo is located
            
                print('build a lv grid for ', str(load_area))
                print('peak_load by ding0', load_area.peak_load)
                print('STARTING SYNTHESIZING LV GRIDS FOR load_area')

                print('CALL')

                print('SYNTHESIZING LV GRIDS for LA TERMINATED')
                
                
        # if only is_aggregated
        #    indent
        load_areas.append(load_area)
# Out:
# build a lv grid for  lv_load_area_4544
# peak_load by ding0 27.9485612387548
# STARTING SYNTHESIZING LV GRIDS FOR load_area
# CALL
# SYNTHESIZING LV GRIDS for LA TERMINATED

# %%
type(fn_fallenbrunnen_la._lv_grid_districts[0])
# Out:
# ding0.core.structure.regions.LVGridDistrictDing0

# %%
fn_fallenbrunnen_la._lv_grid_districts[0].__dict__
# Out:
# {'id_db': 4563,
#  'geo_data': <shapely.geometry.multipolygon.MultiPolygon at 0x21bdc74bf10>,
#  'lv_load_area': lv_load_area_4544,
#  'lv_grid': lv_grid_4563,
#  'population': 80,
#  'peak_load_residential': 27.9485612387548,
#  'peak_load_retail': 0.0,
#  'peak_load_industrial': 0.0,
#  'peak_load_agricultural': 0.0,
#  'peak_load': 27.9485612387548,
#  'sector_count_residential': 1,
#  'sector_count_retail': 0,
#  'sector_count_industrial': 0,
#  'sector_count_agricultural': 0,
#  'sector_consumption_residential': 130771.856816184,
#  'sector_consumption_retail': 0.0,
#  'sector_consumption_industrial': 0.0,
#  'sector_consumption_agricultural': 0.0}

# %%
fn_fallenbrunnen_la.id_db
# Out:
# 4544

# %%
fn_fallenbrunnen_geo = fn_fallenbrunnen_la.geo_area

# %%
#fn_fallenbrunnen_geo.wkt

# %%
from shapely import geometry

# %%
# schnetzenhausen geo
G_east  = 9.4467
G_south = 47.6718
G_north = 47.6790
G_west  = 9.4341

p1 = geometry.Point(G_east,G_south)
p2 = geometry.Point(G_east,G_north)
p3 = geometry.Point(G_west,G_north)
p4 = geometry.Point(G_west,G_south)

pointList = [p1, p2, p3, p4, p1]

area_of_interest = geometry.Polygon([[p.x, p.y] for p in pointList])

area_of_interest.wkt
# Out:
# 'POLYGON ((9.4467 47.6718, 9.4467 47.679, 9.434100000000001 47.679, 9.434100000000001 47.6718, 9.4467 47.6718))'

# %%
# load ways and buildings...

### Load bays
#ways = session_osm.query(Way).filter(func.st_intersects(func.ST_GeomFromText(fn_fallenbrunnen_geo.wkt, get_config_osm('srid')), Way.geometry)) 
ways = session_osm.query(Way).filter(func.st_intersects(func.ST_GeomFromText(area_of_interest.wkt, get_config_osm('srid')), Way.geometry)) 


graph, node_coords_dict = build_graph_from_ways(ways)
#nx.draw(graph, node_coords_dict)


### Load buildings_w_a
#buildings_w_a = session_osm.query(Buildings_with_Amenities).filter(func.st_intersects(func.ST_GeomFromText(fn_fallenbrunnen_geo.wkt, get_config_osm('srid')), Buildings_with_Amenities.geometry_amenity)) 
buildings_w_a = session_osm.query(Buildings_with_Amenities).filter(func.st_intersects(func.ST_GeomFromText(area_of_interest.wkt, get_config_osm('srid')), Buildings_with_Amenities.geometry_amenity)) 

### Load buildings_wo_a
#buildings_wo_a = session_osm.query(Building_wo_Amenity).filter(func.st_intersects(func.ST_GeomFromText(fn_fallenbrunnen_geo.wkt, config_osm['srid']), Building_wo_Amenity.geometry)) 
buildings_wo_a = session_osm.query(Building_wo_Amenity).filter(func.st_intersects(func.ST_GeomFromText(area_of_interest.wkt, get_config_osm('srid')), Building_wo_Amenity.geometry)) 

### Load buildings_wo_a
#amenities_ni_Buildings = session_osm.query(Amenities_ni_Buildings).filter(func.st_intersects(func.ST_GeomFromText(fn_fallenbrunnen_geo.wkt, config_osm['srid']), Amenities_ni_Buildings.geometry)) 
amenities_ni_Buildings = session_osm.query(Amenities_ni_Buildings).filter(func.st_intersects(func.ST_GeomFromText(area_of_interest.wkt, get_config_osm('srid')), Amenities_ni_Buildings.geometry))

# %%
nx.draw(graph, node_coords_dict)

# %% [markdown]
# #### ADD LOADS and ASSIGN NN

# %%
# %%time

# parameterization
buildings_w_loads_df = parameterize_by_load_profiles(buildings_w_a, buildings_wo_a, amenities_ni_Buildings)

# adding nearest nodes
X = buildings_w_loads_df['x'].tolist()
Y = buildings_w_loads_df['y'].tolist()
    
buildings_w_loads_df['nn'], buildings_w_loads_df['nn_dist'] = nearest_nodes(graph, X, Y)
# Out:
# Wall time: 1.3 s

# %%
buildings_w_loads_df.head()
# Out:
#                     category    capacity     area number_households         x  \
# osm_id
# 5175135665  place_of_worship   10.000000      100                 0   9.44044
# 1576076796               pub   60.977231  666.345               3.4  9.441255
# 3461383409        restaurant  150.911429  3298.25              2.16  9.441726
# 8598838279         ice_cream   20.966863  229.121          0.645161  9.437183
# 143475111        residential    0.427118      100              0.25  9.442517
#
#                     y                                           geometry  \
# osm_id
# 5175135665  47.678088                POINT (9.4404395 47.67808800001318)
# 1576076796  47.675475  POLYGON ((9.4410905 47.67549720001377, 9.44114...
# 3461383409  47.675793  POLYGON ((9.441379400000001 47.67584520001369,...
# 8598838279  47.674769  POLYGON ((9.437094099999998 47.67477800001394,...
# 143475111   47.676217  POLYGON ((9.4421704 47.67620580001361, 9.44254...
#
#                                            raccordement          nn    nn_dist
# osm_id
# 5175135665          POINT (9.4404395 47.67808800001318)  2081001741   7.859250
# 1576076796  POINT (9.441254552977929 47.67547454660144)  1863459034  17.760880
# 3461383409  POINT (9.441725733550514 47.67579283860851)  2457005968  30.049377
# 8598838279  POINT (9.437183076702567 47.67476938145773)   475940044  19.021132
# 143475111   POINT (9.442516566727749 47.67621714946911)  3461383425  29.441108

# %%
buildings_w_loads_df.to_csv('buildings_w_loads_df_schnetzenhausen.csv')

# %% [markdown]
# ### Clustering

# %%
n_clusters = get_n_cluster(buildings_w_loads_df)
if n_clusters < len(fn_fallenbrunnen_la._lv_grid_districts):
    n_clusters = len(fn_fallenbrunnen_la._lv_grid_districts)
buildings_w_loads_df = cluster_k_means(buildings_w_loads_df, n_clusters)

# %%
n_clusters
# Out:
# 3

# %% [markdown]
# ### Update and add _districts

# %%
for i in range(n_clusters):
    
    print(len(buildings_w_loads_df.loc[(buildings_w_loads_df['Cluster']==i)]))
# Out:
# 99
# 85
# 79

# %%
buildings_w_loads_df.loc[(buildings_w_loads_df['Cluster']==0)]
# Out:
#                    category    capacity     area number_households         x  \
# osm_id
# 8598838279        ice_cream   20.966863  229.121          0.645161  9.437183
# 144020300   public_building  244.695822  2113.09            0.8125  9.438239
# 144023114            school  102.108142  1641.61          0.552632  9.438521
# 314909001       residential    1.246721      100           0.72973   9.43711
# 314909020             house    1.102239      100          0.645161  9.437548
# ...                     ...         ...      ...               ...       ...
# 314913916       residential    2.904399      100               1.7  9.436301
# 338514542            school  407.558658  6552.39          0.594203  9.438414
# 401560706       residential    1.102239      100          0.645161   9.43769
# 427999640       residential    1.017812      100          0.595745  9.437456
# 428000222       residential    2.628415      100          1.538462  9.436665
#
#                     y                                           geometry  \
# osm_id
# 8598838279  47.674769  POLYGON ((9.437094099999998 47.67477800001394,...
# 144020300   47.675506  POLYGON ((9.437905999999998 47.67551250001376,...
# 144023114   47.673818  POLYGON ((9.438203599999998 47.67375600001416,...
# 314909001   47.674319  POLYGON ((9.4370154 47.67431780001401, 9.43711...
# 314909020   47.674401  POLYGON ((9.4374646 47.674413400014, 9.4375446...
# ...               ...                                                ...
# 314913916   47.672468  POLYGON ((9.436173800000001 47.67246730001447,...
# 338514542   47.673881  POLYGON ((9.437957300000001 47.67387860001414,...
# 401560706   47.674448  POLYGON ((9.4376228 47.674467300014, 9.4377058...
# 427999640   47.673842  POLYGON ((9.4373962 47.67383920001416, 9.43741...
# 428000222   47.673556  POLYGON ((9.436553399999999 47.67355130001422,...
#
#                                            raccordement          nn  \
# osm_id
# 8598838279  POINT (9.437183076702567 47.67476938145773)   475940044
# 144020300   POINT (9.438238891069723 47.67550616796044)  1576023053
# 144023114   POINT (9.438521488700175 47.67381754064048)    68844093
# 314909001   POINT (9.437109750000001 47.67431900001404)  2080880814
# 314909020   POINT (9.437548450000001 47.67440130001403)   314975344
# ...                                                 ...         ...
# 314913916   POINT (9.436301343479869 47.67246766666069)   311379901
# 338514542   POINT (9.438414351486788 47.67388107322754)    68844093
# 401560706   POINT (9.437690147469656 47.67444791593603)   314975344
# 427999640   POINT (9.437456201491505 47.67384173088283)  1863458994
# 428000222   POINT (9.436665109007034 47.67355583574013)  2080880811
#
#               nn_dist  Cluster
# osm_id
# 8598838279  19.021132        0
# 144020300   34.831012        0
# 144023114   33.677840        0
# 314909001   14.638173        0
# 314909020   15.374000        0
# ...               ...      ...
# 314913916   30.431139        0
# 338514542   31.901109        0
# 401560706   27.030240        0
# 427999640   21.084569        0
# 428000222   34.390889        0
#
# [99 rows x 11 columns]

# %%
# %%time

geometry = buildings_w_loads_df.loc[(buildings_w_loads_df['Cluster']==0), 'geometry'].tolist()

points = get_points_in_load_area(geometry)
        
len(points)
# Out:
# Wall time: 9.38 ms
# 140

# %%
get_convex_hull_from_points(points)

# %%
fn_fallenbrunnen_la.lv_load_area_group.__dict__
# Out:
# {'id_db': 20,
#  'mv_grid_district': mv_grid_district_40,
#  '_lv_load_areas': [lv_load_area_4544,
#   lv_load_area_4545,
#   lv_load_area_4548,
#   MVCableDist_mvgd_40_26],
#  'peak_load': 65.35928151751943,
#  'branch_length_sum': 0,
#  'peak_load_max': 1000.0,
#  'branch_length_max': 2000.0,
#  'root_node': MVCableDist_mvgd_40_23}

# %%
nd._mv_grid_districts[0].__dict__
# Out:
# {'id_db': 40,
#  'mv_grid': mv_grid_40,
#  '_lv_load_areas': [lv_load_area_2128,
#   lv_load_area_2292,
#   lv_load_area_2383,
#   lv_load_area_2520,
#   lv_load_area_2521,
#   lv_load_area_2561,
#   lv_load_area_2608,
#   lv_load_area_2625,
#   lv_load_area_2633,
#   lv_load_area_2705,
#   lv_load_area_2728,
#   lv_load_area_2763,
#   lv_load_area_2765,
#   lv_load_area_2840,
#   lv_load_area_2842,
#   lv_load_area_3029,
#   lv_load_area_3088,
#   lv_load_area_3089,
#   lv_load_area_3119,
#   lv_load_area_3160,
#   lv_load_area_3235,
#   lv_load_area_3277,
#   lv_load_area_3304,
#   lv_load_area_3305,
#   lv_load_area_3307,
#   lv_load_area_3311,
#   lv_load_area_3314,
#   lv_load_area_3403,
#   lv_load_area_3413,
#   lv_load_area_3645,
#   lv_load_area_3661,
#   lv_load_area_3731,
#   lv_load_area_3780,
#   lv_load_area_3805,
#   lv_load_area_3911,
#   lv_load_area_3986,
#   lv_load_area_3987,
#   lv_load_area_3992,
#   lv_load_area_4212,
#   lv_load_area_4337,
#   lv_load_area_4347,
#   lv_load_area_4487,
#   lv_load_area_4488,
#   lv_load_area_4544,
#   lv_load_area_4545,
#   lv_load_area_4546,
#   lv_load_area_4547,
#   lv_load_area_4548,
#   lv_load_area_4549,
#   lv_load_area_4550,
#   lv_load_area_4620,
#   lv_load_area_4621,
#   lv_load_area_4622,
#   lv_load_area_4670,
#   lv_load_area_4674,
#   lv_load_area_4735,
#   lv_load_area_4764,
#   lv_load_area_4830,
#   lv_load_area_4831,
#   lv_load_area_4840,
#   lv_load_area_4855,
#   lv_load_area_4868,
#   lv_load_area_4918,
#   lv_load_area_5227,
#   lv_load_area_5305,
#   lv_load_area_5371,
#   lv_load_area_5372,
#   lv_load_area_5404,
#   lv_load_area_5511,
#   lv_load_area_5525,
#   lv_load_area_5529,
#   lv_load_area_5536,
#   lv_load_area_5583,
#   lv_load_area_5588,
#   lv_load_area_5595],
#  '_lv_load_area_groups': [load_area_group_1,
#   load_area_group_2,
#   load_area_group_3,
#   load_area_group_4,
#   load_area_group_5,
#   load_area_group_6,
#   load_area_group_7,
#   load_area_group_8,
#   load_area_group_9,
#   load_area_group_10,
#   load_area_group_11,
#   load_area_group_12,
#   load_area_group_13,
#   load_area_group_14,
#   load_area_group_15,
#   load_area_group_16,
#   load_area_group_17,
#   load_area_group_18,
#   load_area_group_19,
#   load_area_group_20,
#   load_area_group_21,
#   load_area_group_22,
#   load_area_group_23,
#   load_area_group_24,
#   load_area_group_25,
#   load_area_group_26,
#   load_area_group_27,
#   load_area_group_28,
#   load_area_group_29,
#   load_area_group_30,
#   load_area_group_31,
#   load_area_group_32,
#   load_area_group_33,
#   load_area_group_34,
#   load_area_group_35,
#   load_area_group_36,
#   load_area_group_37,
#   load_area_group_38,
#   load_area_group_39],
#  'geo_data': <shapely.geometry.multipolygon.MultiPolygon at 0x1d51256bf10>,
#  'peak_load': 67057.57197852976,
#  'peak_load_satellites': 852.3248953957927,
#  'peak_load_aggregated': 54058.0529320802}

# %%
fn_fallenbrunnen_la._lv_grid_districts[0].lv_grid._station.__dict__
# Out:
# {'id_db': 4563,
#  'geo_data': <shapely.geometry.point.Point at 0x118800eba90>,
#  'grid': lv_grid_4563,
#  '_transformers': [Transformer_lv_grid_4563_1],
#  'v_level_operation': None,
#  'lv_load_area': lv_load_area_4544,
#  'voltage_res': [0.9897135909377942, 1.0123145234795161]}

# %%
preprocessed_clusters = []   
    

for cluster_id in range(n_clusters):
    
    if cluster_id < len(fn_fallenbrunnen_la._lv_grid_districts):
        
        print('delete or update _lv_grid_districts[', cluster_id, ']')
        
        # GET NEW VALUES FOR DISTRICT        
        # get convex hull of cluster
        points = get_points_in_load_area(buildings_w_loads_df.loc[buildings_w_loads_df['Cluster']==cluster_id])
        district_convex_hull = get_convex_hull_from_points(points)
        
        # get location of substation for cluster
        station_x, station_y = get_location_substation_at_pi(graph, buildings_w_loads_df.loc[(buildings_w_loads_df['Cluster']==0)])

        
        # UPDATE VALUES
        # update values of _lv_grid_districts[cluster_id]
        fn_fallenbrunnen_la._lv_grid_districts[cluster_id].geo_data  = district_convex_hull
        fn_fallenbrunnen_la._lv_grid_districts[cluster_id].poulation = buildings_w_loads_df.loc[buildings_w_loads_df['Cluster']==cluster_id]['number_households'].sum()
        
        fn_fallenbrunnen_la._lv_grid_districts[cluster_id].peak_load = buildings_w_loads_df.loc[(buildings_w_loads_df['Cluster']==0)]['capacity'].sum()
        fn_fallenbrunnen_la._lv_grid_districts[cluster_id].peak_load_residential = buildings_w_loads_df.loc[(buildings_w_loads_df['Cluster']==cluster_id) & buildings_w_loads_df['number_households'] > 0]['capacity'].sum()
        
        
        # ADD / RESET DING0 ELEMENTS
        # update position of substation
        fn_fallenbrunnen_la._lv_grid_districts[0].lv_grid._station.geo_data = get_Point_from_x_y(station_x, station_y)
        
        # reset list to add new elements
        fn_fallenbrunnen_la._lv_grid_districts[cluster_id].lv_grid._station.transformers.clear()
        
        
        # update trafo and loads
        #fn_fallenbrunnen_la._lv_grid_districts[cluster_id].lv_grid.build_grid()
        
        
    else:
        
        print('add _lv_grid_districts id', cluster_id)
        
        
        
        
        
    break
# Out:
# update _lv_grid_districts 0
# add _lv_grid_districts id 1
# add _lv_grid_districts id 2

# %%
fn_fallenbrunnen_la._lv_grid_districts[0].lv_grid._station.__dict__
# Out:
# {'id_db': 4563,
#  'geo_data': <shapely.geometry.point.Point at 0x1d50cd257f0>,
#  'grid': lv_grid_4563,
#  '_transformers': [Transformer_lv_grid_4563_1],
#  'v_level_operation': None,
#  'lv_load_area': lv_load_area_4544,
#  'voltage_res': [0.9897135909377942, 1.0123145234795161]}

# %%
#lv_district_of_interest.lv_grid.graph_draw(mode='LV')

# %%
lv_district_of_interest.lv_grid.__dict__ # .geo_data.wkt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-52e70a767919> in <module>
# ----> 1 lv_district_of_interest.lv_grid.__dict__ # .geo_data.wkt
#
# NameError: name 'lv_district_of_interest' is not defined

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# %%
X = []    # collect nodes

for node in graph.nodes:

    X.append([graph.nodes[node]['X'], graph.nodes[node]['Y']])
    
    
X = np.array(X)



# clustering

adj_mat_sparse = nx.adjacency_matrix(graph, weight='length')

clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward', connectivity=adj_mat_sparse).fit(X)






# assign cluster labels

i_label = 0

for node in list(graph.nodes):

    graph.nodes[node]['cluster'] = clustering.labels_[i_label]
    
    i_label += 1
    
labels = nx.get_node_attributes(graph, 'cluster')

# %%
nx.draw(graph, node_coords_dict,labels=labels)

# %%
X = []    # collect nodes

for node in graph.nodes:

    X.append([graph.nodes[node]['X'], graph.nodes[node]['Y']])
    
    
X = np.array(X)



# clustering

adj_mat_sparse = nx.to_numpy_matrix(graph, weight='length')

clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward', connectivity=adj_mat_sparse).fit(X)






# assign cluster labels

i_label = 0

for node in list(graph.nodes):

    graph.nodes[node]['cluster'] = clustering.labels_[i_label]
    
    i_label += 1
    
labels = nx.get_node_attributes(graph, 'cluster')

# %%
nx.draw(graph, node_coords_dict,labels=labels)

# %%
import warnings

from pandas.core.common import SettingWithCopyWarning

warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
# %%capture

from ding0.core import NetworkDing0
from ding0.tools.logger import setup_logger
from ding0.tools.results import save_nd_to_pickle
from ding0.tools.plots import plot_mv_topology
from egoio.tools import db
from sqlalchemy.orm import sessionmaker
import oedialect

from ding0.tools import results # to load pickl file


# create new network
nd = NetworkDing0(name='network')


# set ID of MV grid district
mv_grid_districts = [40] # fn 40, 912

# %% [markdown]
# #### SET DING0 SETTINGS

# %%
# TODO set in config file
ding0_default=False

engine = db.connection(section='oedb_dialect', readonly=True)
session = sessionmaker(bind=engine)()
create_lvgd_geo_method='convex_hull' # off, convex_hull

# %%
# %%time

# STEP 1
nd.import_mv_grid_districts(session, mv_grid_districts_no=mv_grid_districts,
                            ding0_default=ding0_default, need_parameterization=True,
                            create_lvgd_geo_method=create_lvgd_geo_method)
# Out:
# Found connected graph, iteration 0 of max. 4.
# Simplified graph: 3 to 2 nodes, 4 to 2 edges
# all clusters are in range
# Graph already fully connected.
# Simplified graph: 6 to 4 nodes, 10 to 6 edges
# all clusters are in range
# Graph already fully connected.
# Simplified graph: 6 to 2 nodes, 10 to 2 edges
# all clusters are in range
# Finding connected graph, max. iterations 4 trespassed. Break.
# Simplified graph: 18 to 6 nodes, 32 to 8 edges
# Simplified graph: 6 to 5 nodes, 10 to 8 edges
# all clusters are in range
# Finding connected graph, iteration 2 of max. 4.
# Simplified graph: 9 to 5 nodes, 14 to 6 edges
# Simplified graph: 8 to 4 nodes, 14 to 6 edges
# all clusters are in range
# Graph already fully connected.
# Simplified graph: 13 to 10 nodes, 24 to 18 edges
# all clusters are in range
# Graph already fully connected.
# Simplified graph: 7 to 5 nodes, 12 to 8 edges
# all clusters are in range
# Graph already fully connected.
# ...

# %%
import osmnx as ox
cluster_graph = lv_load_area.load_area_graph
nc = ox.plot.get_node_colors_by_attr(cluster_graph, attr='cluster', cmap="Set3") #

fig, ax = ox.plot_graph(cluster_graph, node_color=nc, node_size=10, edge_color='w', edge_linewidth=0.5, show=False, close=False)

for lvgd in lv_load_area._lv_grid_districts:
    ax.scatter(lvgd.lv_grid._station.geo_data.x, lvgd.lv_grid._station.geo_data.y, color = 'red', s=20)

# plot mv loads
for mv_load in mv_grid_district.mv_grid._loads:
    ax.scatter(mv_load.geo_data.x, mv_load.geo_data.y, color = 'cyan', s=20)

# plot load area center
ax.scatter(lv_load_area.lv_load_area_centre.geo_data.x, lv_load_area.lv_load_area_centre.geo_data.y, color = 'white', s=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7036/2937990308.py in <module>
#       1 import osmnx as ox
# ----> 2 cluster_graph = lv_load_area.load_area_graph
#       3 nc = ox.plot.get_node_colors_by_attr(cluster_graph, attr='cluster', cmap="Set3") #
#       4
#       5 fig, ax = ox.plot_graph(cluster_graph, node_color=nc, node_size=10, edge_color='w', edge_linewidth=0.5, show=False, close=False)
#
# NameError: name 'lv_load_area' is not defined

# %%
import osmnx as ox
cluster_graph = lv_load_area.load_area_graph
nc = ox.plot.get_node_colors_by_attr(cluster_graph, attr='cluster', cmap="Set3") #

fig, ax = ox.plot_graph(cluster_graph, node_color=nc, node_size=20, edge_color='w', edge_linewidth=0.5, show=False, close=False)

for lvgd in lv_load_area._lv_grid_districts:
    ax.scatter(lvgd.lv_grid._station.geo_data.x, lvgd.lv_grid._station.geo_data.y, color = 'red', s=20)

# plot mv loads
for mv_load in mv_grid_district.mv_grid._loads:
    ax.scatter(mv_load.geo_data.x, mv_load.geo_data.y, color = 'cyan', s=20)

# %%
# %%time

# STEP 2
nd.import_generators(session, debug=False)
# Out:
# Generator Generator_mvgd_40_lvgd_3986000000_solar_ground_mounted_232522 cannot be assigned to non-existent LV Grid District and was allocated to a random LV Grid District (lv_grid_district_3986000000).
# Generator Generator_mvgd_40_lvgd_4347000059_gas_232523 cannot be assigned to non-existent LV Grid District and was allocated to a random LV Grid District (lv_grid_district_4347000059).
# Generator Generator_mvgd_40_lvgd_4347000049_hydro_232524 has no la_id and was assigned to a random LV Grid District (lv_grid_district_4347000049).
# Generator Generator_mvgd_40_lvgd_4546000000_hydro_232525 has no la_id and was assigned to a random LV Grid District (lv_grid_district_4546000000).
# Generator Generator_mvgd_40_lvgd_4347000063_solar_ground_mounted_232526 cannot be assigned to non-existent LV Grid District and was allocated to a random LV Grid District (lv_grid_district_4347000063).
# ...

# %%
# %%time

# STEP 3
nd.mv_parametrize_grid(debug=False)
# Out:
# Wall time: 23.4 ms

# %%
# STEP 4: Validate MV Grid Districts
msg = nd.validate_grid_districts()

# %%
# %%time

# STEP 5: Build LV grids
# load_area = nd.build_lv_grids()
nd.build_lv_grids()
# Out:
# LV grid building for la lv_load_area_2128
# LVGD building for lv_grid_district_2128000000
# WARNING:ding0:LV grid building for la lv_load_area_2292
# WARNING:ding0:LVGD building for lv_grid_district_2292000000
# WARNING:ding0:LV grid building for la lv_load_area_2383
# WARNING:ding0:LVGD building for lv_grid_district_2383000000
# WARNING:ding0:LV grid building for la lv_load_area_2520
# WARNING:ding0:LVGD building for lv_grid_district_2520000000
# WARNING:ding0:LV grid building for la lv_load_area_2521
# WARNING:ding0:LVGD building for lv_grid_district_2521000000
# WARNING:ding0:LV grid building for la lv_load_area_2561
# WARNING:ding0:LVGD building for lv_grid_district_2561000000
# WARNING:ding0:LV grid building for la lv_load_area_2608
# WARNING:ding0:LVGD building for lv_grid_district_2608000000
# WARNING:ding0:LV grid building for la lv_load_area_2633
# WARNING:ding0:LVGD building for lv_grid_district_2633000000
# WARNING:ding0:LV grid building for la lv_load_area_2705
# ...

# %%
# STEP 6: Build MV grids
nd.mv_routing(debug=False)

# %%
# STEP 7: Connect MV and LV generators
nd.connect_generators(debug=False)

# %%
# STEP 8: Relocate switch disconnectors in MV grid
nd.set_circuit_breakers(debug=False)

# %%
# STEP 9: Open all switch disconnectors in MV grid
nd.control_circuit_breakers(mode='open')

# %%
# STEP 10: Do power flow analysis of MV grid
nd.run_powerflow(session, method='onthefly', export_pypsa=True, debug=False)
